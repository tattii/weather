# %%
# %matplotlib inline 
from mpl_toolkits.basemap import Basemap 
import numpy as np
import matplotlib.pyplot as plt
import pygrib
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
grbs = pygrib.open('gfs_4_20160219_0600_000.grb2')

# %%
def pd_grib_inventory(grbs):
    grbs.seek(0)
    df = pd.DataFrame(columns=['name', 'units' , 'level', 'valid', 'data'])
    for grb in grbs:
        df.loc[len(df) + 1] = [
            grb.name,
            grb.units,
            grb.typeOfLevel + ": " + str(grb.level),
            grb.validityDate * 10000 + grb.validityTime,
            grb.dataDate * 10000 + grb.dataTime
        ]
    return df

# %%
pd_grib_inventory(grbs)
# Out:
#                                                name       units  \
# 1                               U component of wind     m s**-1
# 2                               V component of wind     m s**-1
# 3                                           unknown     unknown
# 4                                 Wind speed (gust)     m s**-1
# 5                               Geopotential Height         gpm
# 6                                       Temperature           K
# 7                                 Relative humidity           %
# 8                               U component of wind     m s**-1
# 9                               V component of wind     m s**-1
# 10                               Absolute vorticity       s**-1
# 11                               Ozone mixing ratio   kg kg**-1
# 12                              Geopotential Height         gpm
# 13                                      Temperature           K
# 14                                Relative humidity           %
# 15                              U component of wind     m s**-1
# 16                              V component of wind     m s**-1
# 17                               Absolute vorticity       s**-1
# 18                               Ozone mixing ratio   kg kg**-1
# 19                              Geopotential Height         gpm
# 20                                      Temperature           K
# 21                                Relative humidity           %
# 22                              U component of wind     m s**-1
# 23                              V component of wind     m s**-1
# 24                               Absolute vorticity       s**-1
# 25                               Ozone mixing ratio   kg kg**-1
# 26                              Geopotential Height         gpm
# 27                                      Temperature           K
# 28                                Relative humidity           %
# 29                              U component of wind     m s**-1
# 30                              V component of wind     m s**-1
# 31                               Absolute vorticity       s**-1
# 32                               Ozone mixing ratio   kg kg**-1
# 33                              Geopotential Height         gpm
# 34                                      Temperature           K
# 35                                Relative humidity           %
# 36                              U component of wind     m s**-1
# 37                              V component of wind     m s**-1
# 38                               Absolute vorticity       s**-1
# 39                               Ozone mixing ratio   kg kg**-1
# 40                              Geopotential Height         gpm
# 41                                      Temperature           K
# 42                                Relative humidity           %
# 43                                Vertical velocity    Pa s**-1
# 44                              U component of wind     m s**-1
# 45                              V component of wind     m s**-1
# 46                               Absolute vorticity       s**-1
# 47                               Cloud mixing ratio   kg kg**-1
# 48                               Ozone mixing ratio   kg kg**-1
# 49                              Geopotential Height         gpm
# 50                                      Temperature           K
# 51                                Relative humidity           %
# 52                                Vertical velocity    Pa s**-1
# 53                              U component of wind     m s**-1
# 54                              V component of wind     m s**-1
# 55                               Absolute vorticity       s**-1
# 56                               Cloud mixing ratio   kg kg**-1
# 57                               Ozone mixing ratio   kg kg**-1
# 58                              Geopotential Height         gpm
# 59                                      Temperature           K
# 60                                Relative humidity           %
# 61                                Vertical velocity    Pa s**-1
# 62                              U component of wind     m s**-1
# 63                              V component of wind     m s**-1
# 64                               Absolute vorticity       s**-1
# 65                               Cloud mixing ratio   kg kg**-1
# 66                               Ozone mixing ratio   kg kg**-1
# 67                              Geopotential Height         gpm
# 68                                      Temperature           K
# 69                                Relative humidity           %
# 70                                Vertical velocity    Pa s**-1
# 71                              U component of wind     m s**-1
# 72                              V component of wind     m s**-1
# 73                               Absolute vorticity       s**-1
# 74                               Cloud mixing ratio   kg kg**-1
# 75                               Ozone mixing ratio   kg kg**-1
# 76                              Geopotential Height         gpm
# 77                                      Temperature           K
# 78                                Relative humidity           %
# 79                                Vertical velocity    Pa s**-1
# 80                              U component of wind     m s**-1
# 81                              V component of wind     m s**-1
# 82                               Absolute vorticity       s**-1
# 83                               Cloud mixing ratio   kg kg**-1
# 84                               Ozone mixing ratio   kg kg**-1
# 85                              Geopotential Height         gpm
# 86                                      Temperature           K
# 87                                Relative humidity           %
# 88                                Vertical velocity    Pa s**-1
# 89                              U component of wind     m s**-1
# 90                              V component of wind     m s**-1
# 91                               Absolute vorticity       s**-1
# 92                               Cloud mixing ratio   kg kg**-1
# 93                               Ozone mixing ratio   kg kg**-1
# 94                              Geopotential Height         gpm
# 95                                      Temperature           K
# 96                                Relative humidity           %
# 97                                Vertical velocity    Pa s**-1
# 98                              U component of wind     m s**-1
# 99                              V component of wind     m s**-1
# 100                              Absolute vorticity       s**-1
# 101                              Cloud mixing ratio   kg kg**-1
# 102                              Ozone mixing ratio   kg kg**-1
# 103                             Geopotential Height         gpm
# 104                                     Temperature           K
# 105                               Relative humidity           %
# 106                               Vertical velocity    Pa s**-1
# 107                             U component of wind     m s**-1
# 108                             V component of wind     m s**-1
# 109                              Absolute vorticity       s**-1
# 110                              Cloud mixing ratio   kg kg**-1
# 111                             Geopotential Height         gpm
# 112                                     Temperature           K
# 113                               Relative humidity           %
# 114                               Vertical velocity    Pa s**-1
# 115                             U component of wind     m s**-1
# 116                             V component of wind     m s**-1
# 117                              Absolute vorticity       s**-1
# 118                              Cloud mixing ratio   kg kg**-1
# 119                             Geopotential Height         gpm
# 120                                     Temperature           K
# 121                               Relative humidity           %
# 122                               Vertical velocity    Pa s**-1
# 123                             U component of wind     m s**-1
# 124                             V component of wind     m s**-1
# 125                              Absolute vorticity       s**-1
# 126                              Cloud mixing ratio   kg kg**-1
# 127                             Geopotential Height         gpm
# 128                                     Temperature           K
# 129                               Relative humidity           %
# 130                               Vertical velocity    Pa s**-1
# 131                             U component of wind     m s**-1
# 132                             V component of wind     m s**-1
# 133                              Absolute vorticity       s**-1
# 134                              Cloud mixing ratio   kg kg**-1
# 135                             Geopotential Height         gpm
# 136                                     Temperature           K
# 137                               Relative humidity           %
# 138                               Vertical velocity    Pa s**-1
# 139                             U component of wind     m s**-1
# 140                             V component of wind     m s**-1
# 141                              Absolute vorticity       s**-1
# 142                              Cloud mixing ratio   kg kg**-1
# 143                             Geopotential Height         gpm
# 144                                     Temperature           K
# 145                               Relative humidity           %
# 146                               Vertical velocity    Pa s**-1
# 147                             U component of wind     m s**-1
# 148                             V component of wind     m s**-1
# 149                              Absolute vorticity       s**-1
# 150                              Cloud mixing ratio   kg kg**-1
# 151                             Geopotential Height         gpm
# 152                                     Temperature           K
# 153                               Relative humidity           %
# 154                               Vertical velocity    Pa s**-1
# 155                             U component of wind     m s**-1
# 156                             V component of wind     m s**-1
# 157                              Absolute vorticity       s**-1
# 158                              Cloud mixing ratio   kg kg**-1
# 159                             Geopotential Height         gpm
# 160                                     Temperature           K
# 161                               Relative humidity           %
# 162                               Vertical velocity    Pa s**-1
# 163                             U component of wind     m s**-1
# 164                             V component of wind     m s**-1
# 165                              Absolute vorticity       s**-1
# 166                              Cloud mixing ratio   kg kg**-1
# 167                             Geopotential Height         gpm
# 168                                     Temperature           K
# 169                               Relative humidity           %
# 170                               Vertical velocity    Pa s**-1
# 171                             U component of wind     m s**-1
# 172                             V component of wind     m s**-1
# 173                              Absolute vorticity       s**-1
# 174                              Cloud mixing ratio   kg kg**-1
# 175                             Geopotential Height         gpm
# 176                                     Temperature           K
# 177                               Relative humidity           %
# 178                               Vertical velocity    Pa s**-1
# 179                             U component of wind     m s**-1
# 180                             V component of wind     m s**-1
# 181                              Absolute vorticity       s**-1
# 182                              Cloud mixing ratio   kg kg**-1
# 183                             Geopotential Height         gpm
# 184                                     Temperature           K
# 185                               Relative humidity           %
# 186                               Vertical velocity    Pa s**-1
# 187                             U component of wind     m s**-1
# 188                             V component of wind     m s**-1
# 189                              Absolute vorticity       s**-1
# 190                              Cloud mixing ratio   kg kg**-1
# 191                             Geopotential Height         gpm
# 192                                     Temperature           K
# 193                               Relative humidity           %
# 194                               Vertical velocity    Pa s**-1
# 195                             U component of wind     m s**-1
# 196                             V component of wind     m s**-1
# 197                              Absolute vorticity       s**-1
# 198                              Cloud mixing ratio   kg kg**-1
# 199                                         unknown     unknown
# 200                             Geopotential Height         gpm
# 201                                     Temperature           K
# 202                               Relative humidity           %
# 203                               Vertical velocity    Pa s**-1
# 204                             U component of wind     m s**-1
# 205                             V component of wind     m s**-1
# 206                              Absolute vorticity       s**-1
# 207                              Cloud mixing ratio   kg kg**-1
# 208                                     Temperature           K
# 209                               Relative humidity           %
# 210                               Vertical velocity    Pa s**-1
# 211                             U component of wind     m s**-1
# 212                             V component of wind     m s**-1
# 213                              Absolute vorticity       s**-1
# 214                              Cloud mixing ratio   kg kg**-1
# 215                      MSLP (Eta model reduction)          Pa
# 216                             Geopotential Height         gpm
# 217                                Surface pressure          Pa
# 218                                       Orography           m
# 219                                     Temperature           K
# 220                                Soil Temperature           K
# 221                Volumetric soil moisture content  Proportion
# 222                                Soil Temperature           K
# 223                Volumetric soil moisture content  Proportion
# 224                                Soil Temperature           K
# 225                Volumetric soil moisture content  Proportion
# 226                                Soil Temperature           K
# 227                Volumetric soil moisture content  Proportion
# 228      Water equivalent of accumulated snow depth    kg m**-2
# 229      Water equivalent of accumulated snow depth    kg m**-2
# 230                             2 metre temperature           K
# 231                               Specific humidity   kg kg**-1
# 232                    2 metre dewpoint temperature           K
# 233                               Relative humidity           %
# 234                                         unknown     unknown
# 235                       10 metre U wind component     m s**-1
# 236                       10 metre V wind component     m s**-1
# 237                    Percent frozen precipitation           %
# 238                                   Wilting Point    Fraction
# 239                                  Field Capacity    Fraction
# 240                                         unknown     unknown
# 241                            Surface lifted index           K
# 242           Convective available potential energy    J kg**-1
# 243                           Convective inhibition    J kg**-1
# 244                              Precipitable water    kg m**-2
# 245                                     Cloud water    kg m**-2
# 246                               Relative humidity           %
# 247                                     Total ozone      Dobson
# 248                         Storm relative helicity    J kg**-1
# 249                        U-component storm motion     m s**-1
# 250                        V-component storm motion     m s**-1
# 251                                        Pressure          Pa
# 252       ICAO Standard Atmosphere reference height           m
# 253                             Geopotential Height         gpm
# 254                                     Temperature           K
# 255                             U component of wind     m s**-1
# 256                             V component of wind     m s**-1
# 257                            Vertical speed shear       s**-1
# 258                                        Pressure          Pa
# 259       ICAO Standard Atmosphere reference height           m
# 260                             Geopotential Height         gpm
# 261                             U component of wind     m s**-1
# 262                             V component of wind     m s**-1
# 263                                     Temperature           K
# 264                             2 metre temperature           K
# 265                               Specific humidity   kg kg**-1
# 266                                        Pressure          Pa
# 267                             U component of wind     m s**-1
# 268                             V component of wind     m s**-1
# 269                             2 metre temperature           K
# 270                             U component of wind     m s**-1
# 271                             V component of wind     m s**-1
# 272                                     Temperature           K
# 273                             U component of wind     m s**-1
# 274                             V component of wind     m s**-1
# 275                                     Temperature           K
# 276                             U component of wind     m s**-1
# 277                             V component of wind     m s**-1
# 278                                     Temperature           K
# 279                             U component of wind     m s**-1
# 280                             V component of wind     m s**-1
# 281                             Geopotential Height         gpm
# 282                               Relative humidity           %
# 283                             Geopotential Height         gpm
# 284                               Relative humidity           %
# 285                                     Temperature           K
# 286                               Relative humidity           %
# 287                               Specific humidity   kg kg**-1
# 288                             U component of wind     m s**-1
# 289                             V component of wind     m s**-1
# 290                     Best (4-layer) lifted index           K
# 291           Convective available potential energy    J kg**-1
# 292                           Convective inhibition    J kg**-1
# 293                 Planetary boundary layer height           m
# 294                               Relative humidity           %
# 295                               Relative humidity           %
# 296                               Relative humidity           %
# 297                               Relative humidity           %
# 298                                     Temperature           K
# 299                           Potential temperature           K
# 300                               Relative humidity           %
# 301                             U component of wind     m s**-1
# 302                             V component of wind     m s**-1
# 303                               Vertical velocity    Pa s**-1
# 304           Convective available potential energy    J kg**-1
# 305                           Convective inhibition    J kg**-1
# 306  Pressure of level from which parcel was lifted          Pa
# 307                                   Land-sea mask     (0 - 1)
# 308                                       Ice cover  Proportion
# 309                             U component of wind     m s**-1
# 310                             V component of wind     m s**-1
# 311                                     Temperature           K
# 312                             Geopotential Height         gpm
# 313                                        Pressure          Pa
# 314                            Vertical speed shear       s**-1
# 315                             U component of wind     m s**-1
# 316                             V component of wind     m s**-1
# 317                                     Temperature           K
# 318                             Geopotential Height         gpm
# 319                                        Pressure          Pa
# 320                            Vertical speed shear       s**-1
# 321                         Pressure reduced to MSL          Pa
# 322                      5-wave geopotential height         gpm
#
#                               level         valid          data
# 1                        unknown: 0  201602190600  201602190600
# 2                        unknown: 0  201602190600  201602190600
# 3                        unknown: 0  201602190600  201602190600
# 4                        surface: 0  201602190600  201602190600
# 5                 isobaricInhPa: 10  201602190600  201602190600
# 6                 isobaricInhPa: 10  201602190600  201602190600
# 7                 isobaricInhPa: 10  201602190600  201602190600
# 8                 isobaricInhPa: 10  201602190600  201602190600
# 9                 isobaricInhPa: 10  201602190600  201602190600
# 10                isobaricInhPa: 10  201602190600  201602190600
# 11                isobaricInhPa: 10  201602190600  201602190600
# 12                isobaricInhPa: 20  201602190600  201602190600
# 13                isobaricInhPa: 20  201602190600  201602190600
# 14                isobaricInhPa: 20  201602190600  201602190600
# 15                isobaricInhPa: 20  201602190600  201602190600
# 16                isobaricInhPa: 20  201602190600  201602190600
# 17                isobaricInhPa: 20  201602190600  201602190600
# 18                isobaricInhPa: 20  201602190600  201602190600
# 19                isobaricInhPa: 30  201602190600  201602190600
# 20                isobaricInhPa: 30  201602190600  201602190600
# 21                isobaricInhPa: 30  201602190600  201602190600
# 22                isobaricInhPa: 30  201602190600  201602190600
# 23                isobaricInhPa: 30  201602190600  201602190600
# 24                isobaricInhPa: 30  201602190600  201602190600
# 25                isobaricInhPa: 30  201602190600  201602190600
# 26                isobaricInhPa: 50  201602190600  201602190600
# 27                isobaricInhPa: 50  201602190600  201602190600
# 28                isobaricInhPa: 50  201602190600  201602190600
# 29                isobaricInhPa: 50  201602190600  201602190600
# 30                isobaricInhPa: 50  201602190600  201602190600
# 31                isobaricInhPa: 50  201602190600  201602190600
# 32                isobaricInhPa: 50  201602190600  201602190600
# 33                isobaricInhPa: 70  201602190600  201602190600
# 34                isobaricInhPa: 70  201602190600  201602190600
# 35                isobaricInhPa: 70  201602190600  201602190600
# 36                isobaricInhPa: 70  201602190600  201602190600
# 37                isobaricInhPa: 70  201602190600  201602190600
# 38                isobaricInhPa: 70  201602190600  201602190600
# 39                isobaricInhPa: 70  201602190600  201602190600
# 40               isobaricInhPa: 100  201602190600  201602190600
# 41               isobaricInhPa: 100  201602190600  201602190600
# 42               isobaricInhPa: 100  201602190600  201602190600
# 43               isobaricInhPa: 100  201602190600  201602190600
# 44               isobaricInhPa: 100  201602190600  201602190600
# 45               isobaricInhPa: 100  201602190600  201602190600
# 46               isobaricInhPa: 100  201602190600  201602190600
# 47               isobaricInhPa: 100  201602190600  201602190600
# 48               isobaricInhPa: 100  201602190600  201602190600
# 49               isobaricInhPa: 150  201602190600  201602190600
# 50               isobaricInhPa: 150  201602190600  201602190600
# 51               isobaricInhPa: 150  201602190600  201602190600
# 52               isobaricInhPa: 150  201602190600  201602190600
# 53               isobaricInhPa: 150  201602190600  201602190600
# 54               isobaricInhPa: 150  201602190600  201602190600
# 55               isobaricInhPa: 150  201602190600  201602190600
# 56               isobaricInhPa: 150  201602190600  201602190600
# 57               isobaricInhPa: 150  201602190600  201602190600
# 58               isobaricInhPa: 200  201602190600  201602190600
# 59               isobaricInhPa: 200  201602190600  201602190600
# 60               isobaricInhPa: 200  201602190600  201602190600
# 61               isobaricInhPa: 200  201602190600  201602190600
# 62               isobaricInhPa: 200  201602190600  201602190600
# 63               isobaricInhPa: 200  201602190600  201602190600
# 64               isobaricInhPa: 200  201602190600  201602190600
# 65               isobaricInhPa: 200  201602190600  201602190600
# 66               isobaricInhPa: 200  201602190600  201602190600
# 67               isobaricInhPa: 250  201602190600  201602190600
# 68               isobaricInhPa: 250  201602190600  201602190600
# 69               isobaricInhPa: 250  201602190600  201602190600
# 70               isobaricInhPa: 250  201602190600  201602190600
# 71               isobaricInhPa: 250  201602190600  201602190600
# 72               isobaricInhPa: 250  201602190600  201602190600
# 73               isobaricInhPa: 250  201602190600  201602190600
# 74               isobaricInhPa: 250  201602190600  201602190600
# 75               isobaricInhPa: 250  201602190600  201602190600
# 76               isobaricInhPa: 300  201602190600  201602190600
# 77               isobaricInhPa: 300  201602190600  201602190600
# 78               isobaricInhPa: 300  201602190600  201602190600
# 79               isobaricInhPa: 300  201602190600  201602190600
# 80               isobaricInhPa: 300  201602190600  201602190600
# 81               isobaricInhPa: 300  201602190600  201602190600
# 82               isobaricInhPa: 300  201602190600  201602190600
# 83               isobaricInhPa: 300  201602190600  201602190600
# 84               isobaricInhPa: 300  201602190600  201602190600
# 85               isobaricInhPa: 350  201602190600  201602190600
# 86               isobaricInhPa: 350  201602190600  201602190600
# 87               isobaricInhPa: 350  201602190600  201602190600
# 88               isobaricInhPa: 350  201602190600  201602190600
# 89               isobaricInhPa: 350  201602190600  201602190600
# 90               isobaricInhPa: 350  201602190600  201602190600
# 91               isobaricInhPa: 350  201602190600  201602190600
# 92               isobaricInhPa: 350  201602190600  201602190600
# 93               isobaricInhPa: 350  201602190600  201602190600
# 94               isobaricInhPa: 400  201602190600  201602190600
# 95               isobaricInhPa: 400  201602190600  201602190600
# 96               isobaricInhPa: 400  201602190600  201602190600
# 97               isobaricInhPa: 400  201602190600  201602190600
# 98               isobaricInhPa: 400  201602190600  201602190600
# 99               isobaricInhPa: 400  201602190600  201602190600
# 100              isobaricInhPa: 400  201602190600  201602190600
# 101              isobaricInhPa: 400  201602190600  201602190600
# 102              isobaricInhPa: 400  201602190600  201602190600
# 103              isobaricInhPa: 450  201602190600  201602190600
# 104              isobaricInhPa: 450  201602190600  201602190600
# 105              isobaricInhPa: 450  201602190600  201602190600
# 106              isobaricInhPa: 450  201602190600  201602190600
# 107              isobaricInhPa: 450  201602190600  201602190600
# 108              isobaricInhPa: 450  201602190600  201602190600
# 109              isobaricInhPa: 450  201602190600  201602190600
# 110              isobaricInhPa: 450  201602190600  201602190600
# 111              isobaricInhPa: 500  201602190600  201602190600
# 112              isobaricInhPa: 500  201602190600  201602190600
# 113              isobaricInhPa: 500  201602190600  201602190600
# 114              isobaricInhPa: 500  201602190600  201602190600
# 115              isobaricInhPa: 500  201602190600  201602190600
# 116              isobaricInhPa: 500  201602190600  201602190600
# 117              isobaricInhPa: 500  201602190600  201602190600
# 118              isobaricInhPa: 500  201602190600  201602190600
# 119              isobaricInhPa: 550  201602190600  201602190600
# 120              isobaricInhPa: 550  201602190600  201602190600
# 121              isobaricInhPa: 550  201602190600  201602190600
# 122              isobaricInhPa: 550  201602190600  201602190600
# 123              isobaricInhPa: 550  201602190600  201602190600
# 124              isobaricInhPa: 550  201602190600  201602190600
# 125              isobaricInhPa: 550  201602190600  201602190600
# 126              isobaricInhPa: 550  201602190600  201602190600
# 127              isobaricInhPa: 600  201602190600  201602190600
# 128              isobaricInhPa: 600  201602190600  201602190600
# 129              isobaricInhPa: 600  201602190600  201602190600
# 130              isobaricInhPa: 600  201602190600  201602190600
# 131              isobaricInhPa: 600  201602190600  201602190600
# 132              isobaricInhPa: 600  201602190600  201602190600
# 133              isobaricInhPa: 600  201602190600  201602190600
# 134              isobaricInhPa: 600  201602190600  201602190600
# 135              isobaricInhPa: 650  201602190600  201602190600
# 136              isobaricInhPa: 650  201602190600  201602190600
# 137              isobaricInhPa: 650  201602190600  201602190600
# 138              isobaricInhPa: 650  201602190600  201602190600
# 139              isobaricInhPa: 650  201602190600  201602190600
# 140              isobaricInhPa: 650  201602190600  201602190600
# 141              isobaricInhPa: 650  201602190600  201602190600
# 142              isobaricInhPa: 650  201602190600  201602190600
# 143              isobaricInhPa: 700  201602190600  201602190600
# 144              isobaricInhPa: 700  201602190600  201602190600
# 145              isobaricInhPa: 700  201602190600  201602190600
# 146              isobaricInhPa: 700  201602190600  201602190600
# 147              isobaricInhPa: 700  201602190600  201602190600
# 148              isobaricInhPa: 700  201602190600  201602190600
# 149              isobaricInhPa: 700  201602190600  201602190600
# 150              isobaricInhPa: 700  201602190600  201602190600
# 151              isobaricInhPa: 750  201602190600  201602190600
# 152              isobaricInhPa: 750  201602190600  201602190600
# 153              isobaricInhPa: 750  201602190600  201602190600
# 154              isobaricInhPa: 750  201602190600  201602190600
# 155              isobaricInhPa: 750  201602190600  201602190600
# 156              isobaricInhPa: 750  201602190600  201602190600
# 157              isobaricInhPa: 750  201602190600  201602190600
# 158              isobaricInhPa: 750  201602190600  201602190600
# 159              isobaricInhPa: 800  201602190600  201602190600
# 160              isobaricInhPa: 800  201602190600  201602190600
# 161              isobaricInhPa: 800  201602190600  201602190600
# 162              isobaricInhPa: 800  201602190600  201602190600
# 163              isobaricInhPa: 800  201602190600  201602190600
# 164              isobaricInhPa: 800  201602190600  201602190600
# 165              isobaricInhPa: 800  201602190600  201602190600
# 166              isobaricInhPa: 800  201602190600  201602190600
# 167              isobaricInhPa: 850  201602190600  201602190600
# 168              isobaricInhPa: 850  201602190600  201602190600
# 169              isobaricInhPa: 850  201602190600  201602190600
# 170              isobaricInhPa: 850  201602190600  201602190600
# 171              isobaricInhPa: 850  201602190600  201602190600
# 172              isobaricInhPa: 850  201602190600  201602190600
# 173              isobaricInhPa: 850  201602190600  201602190600
# 174              isobaricInhPa: 850  201602190600  201602190600
# 175              isobaricInhPa: 900  201602190600  201602190600
# 176              isobaricInhPa: 900  201602190600  201602190600
# 177              isobaricInhPa: 900  201602190600  201602190600
# 178              isobaricInhPa: 900  201602190600  201602190600
# 179              isobaricInhPa: 900  201602190600  201602190600
# 180              isobaricInhPa: 900  201602190600  201602190600
# 181              isobaricInhPa: 900  201602190600  201602190600
# 182              isobaricInhPa: 900  201602190600  201602190600
# 183              isobaricInhPa: 925  201602190600  201602190600
# 184              isobaricInhPa: 925  201602190600  201602190600
# 185              isobaricInhPa: 925  201602190600  201602190600
# 186              isobaricInhPa: 925  201602190600  201602190600
# 187              isobaricInhPa: 925  201602190600  201602190600
# 188              isobaricInhPa: 925  201602190600  201602190600
# 189              isobaricInhPa: 925  201602190600  201602190600
# 190              isobaricInhPa: 925  201602190600  201602190600
# 191              isobaricInhPa: 950  201602190600  201602190600
# 192              isobaricInhPa: 950  201602190600  201602190600
# 193              isobaricInhPa: 950  201602190600  201602190600
# 194              isobaricInhPa: 950  201602190600  201602190600
# 195              isobaricInhPa: 950  201602190600  201602190600
# 196              isobaricInhPa: 950  201602190600  201602190600
# 197              isobaricInhPa: 950  201602190600  201602190600
# 198              isobaricInhPa: 950  201602190600  201602190600
# 199                      surface: 0  201602190600  201602190600
# 200              isobaricInhPa: 975  201602190600  201602190600
# 201              isobaricInhPa: 975  201602190600  201602190600
# 202              isobaricInhPa: 975  201602190600  201602190600
# 203              isobaricInhPa: 975  201602190600  201602190600
# 204              isobaricInhPa: 975  201602190600  201602190600
# 205              isobaricInhPa: 975  201602190600  201602190600
# 206              isobaricInhPa: 975  201602190600  201602190600
# 207              isobaricInhPa: 975  201602190600  201602190600
# 208             isobaricInhPa: 1000  201602190600  201602190600
# 209             isobaricInhPa: 1000  201602190600  201602190600
# 210             isobaricInhPa: 1000  201602190600  201602190600
# 211             isobaricInhPa: 1000  201602190600  201602190600
# 212             isobaricInhPa: 1000  201602190600  201602190600
# 213             isobaricInhPa: 1000  201602190600  201602190600
# 214             isobaricInhPa: 1000  201602190600  201602190600
# 215                      meanSea: 0  201602190600  201602190600
# 216             isobaricInhPa: 1000  201602190600  201602190600
# 217                      surface: 0  201602190600  201602190600
# 218                      surface: 0  201602190600  201602190600
# 219                      surface: 0  201602190600  201602190600
# 220          depthBelowLandLayer: 0  201602190600  201602190600
# 221          depthBelowLandLayer: 0  201602190600  201602190600
# 222          depthBelowLandLayer: 0  201602190600  201602190600
# 223          depthBelowLandLayer: 0  201602190600  201602190600
# 224          depthBelowLandLayer: 0  201602190600  201602190600
# 225          depthBelowLandLayer: 0  201602190600  201602190600
# 226          depthBelowLandLayer: 1  201602190600  201602190600
# 227          depthBelowLandLayer: 1  201602190600  201602190600
# 228                      surface: 0  201602190600  201602190600
# 229                      surface: 0  201602190600  201602190600
# 230            heightAboveGround: 2  201602190600  201602190600
# 231            heightAboveGround: 2  201602190600  201602190600
# 232            heightAboveGround: 2  201602190600  201602190600
# 233            heightAboveGround: 2  201602190600  201602190600
# 234            heightAboveGround: 2  201602190600  201602190600
# 235           heightAboveGround: 10  201602190600  201602190600
# 236           heightAboveGround: 10  201602190600  201602190600
# 237                      surface: 0  201602190600  201602190600
# 238                      surface: 0  201602190600  201602190600
# 239                      surface: 0  201602190600  201602190600
# 240                      surface: 0  201602190600  201602190600
# 241                      surface: 0  201602190600  201602190600
# 242                      surface: 0  201602190600  201602190600
# 243                      surface: 0  201602190600  201602190600
# 244                      unknown: 0  201602190600  201602190600
# 245                      unknown: 0  201602190600  201602190600
# 246                      unknown: 0  201602190600  201602190600
# 247                      unknown: 0  201602190600  201602190600
# 248    heightAboveGroundLayer: 3000  201602190600  201602190600
# 249    heightAboveGroundLayer: 6000  201602190600  201602190600
# 250    heightAboveGroundLayer: 6000  201602190600  201602190600
# 251                   tropopause: 0  201602190600  201602190600
# 252                   tropopause: 0  201602190600  201602190600
# 253                   tropopause: 0  201602190600  201602190600
# 254                   tropopause: 0  201602190600  201602190600
# 255                   tropopause: 0  201602190600  201602190600
# 256                   tropopause: 0  201602190600  201602190600
# 257                   tropopause: 0  201602190600  201602190600
# 258                      maxWind: 0  201602190600  201602190600
# 259                      maxWind: 0  201602190600  201602190600
# 260                      maxWind: 0  201602190600  201602190600
# 261                      maxWind: 0  201602190600  201602190600
# 262                      maxWind: 0  201602190600  201602190600
# 263                      maxWind: 0  201602190600  201602190600
# 264           heightAboveGround: 80  201602190600  201602190600
# 265           heightAboveGround: 80  201602190600  201602190600
# 266           heightAboveGround: 80  201602190600  201602190600
# 267           heightAboveGround: 80  201602190600  201602190600
# 268           heightAboveGround: 80  201602190600  201602190600
# 269          heightAboveGround: 100  201602190600  201602190600
# 270          heightAboveGround: 100  201602190600  201602190600
# 271          heightAboveGround: 100  201602190600  201602190600
# 272            heightAboveSea: 1829  201602190600  201602190600
# 273            heightAboveSea: 1829  201602190600  201602190600
# 274            heightAboveSea: 1829  201602190600  201602190600
# 275            heightAboveSea: 2743  201602190600  201602190600
# 276            heightAboveSea: 2743  201602190600  201602190600
# 277            heightAboveSea: 2743  201602190600  201602190600
# 278            heightAboveSea: 3658  201602190600  201602190600
# 279            heightAboveSea: 3658  201602190600  201602190600
# 280            heightAboveSea: 3658  201602190600  201602190600
# 281                 isothermZero: 0  201602190600  201602190600
# 282                 isothermZero: 0  201602190600  201602190600
# 283                      unknown: 0  201602190600  201602190600
# 284                      unknown: 0  201602190600  201602190600
# 285   pressureFromGroundLayer: 3000  201602190600  201602190600
# 286   pressureFromGroundLayer: 3000  201602190600  201602190600
# 287   pressureFromGroundLayer: 3000  201602190600  201602190600
# 288   pressureFromGroundLayer: 3000  201602190600  201602190600
# 289   pressureFromGroundLayer: 3000  201602190600  201602190600
# 290                      surface: 0  201602190600  201602190600
# 291  pressureFromGroundLayer: 18000  201602190600  201602190600
# 292  pressureFromGroundLayer: 18000  201602190600  201602190600
# 293                      surface: 0  201602190600  201602190600
# 294                   sigmaLayer: 0  201602190600  201602190600
# 295                   sigmaLayer: 0  201602190600  201602190600
# 296                   sigmaLayer: 1  201602190600  201602190600
# 297                   sigmaLayer: 0  201602190600  201602190600
# 298                        sigma: 1  201602190600  201602190600
# 299                        sigma: 1  201602190600  201602190600
# 300                        sigma: 1  201602190600  201602190600
# 301                        sigma: 1  201602190600  201602190600
# 302                        sigma: 1  201602190600  201602190600
# 303                        sigma: 1  201602190600  201602190600
# 304  pressureFromGroundLayer: 25500  201602190600  201602190600
# 305  pressureFromGroundLayer: 25500  201602190600  201602190600
# 306  pressureFromGroundLayer: 25500  201602190600  201602190600
# 307                      surface: 0  201602190600  201602190600
# 308                      surface: 0  201602190600  201602190600
# 309           potentialVorticity: 2  201602190600  201602190600
# 310           potentialVorticity: 2  201602190600  201602190600
# 311           potentialVorticity: 2  201602190600  201602190600
# 312           potentialVorticity: 2  201602190600  201602190600
# 313           potentialVorticity: 2  201602190600  201602190600
# 314           potentialVorticity: 2  201602190600  201602190600
# 315     potentialVorticity: 2147486  201602190600  201602190600
# 316     potentialVorticity: 2147486  201602190600  201602190600
# 317     potentialVorticity: 2147486  201602190600  201602190600
# 318     potentialVorticity: 2147486  201602190600  201602190600
# 319     potentialVorticity: 2147486  201602190600  201602190600
# 320     potentialVorticity: 2147486  201602190600  201602190600
# 321                      meanSea: 0  201602190600  201602190600
# 322              isobaricInhPa: 500  201602190600  201602190600

# %%
grbs[1].keys()
# Out:
# [u'parametersVersion',
#  u'hundred',
#  u'globalDomain',
#  u'GRIBEditionNumber',
#  u'grib2divider',
#  u'missingValue',
#  u'ieeeFloats',
#  u'section0Length',
#  u'identifier',
#  u'discipline',
#  u'editionNumber',
#  u'totalLength',
#  u'sectionNumber',
#  u'section1Length',
#  u'numberOfSection',
#  u'centre',
#  u'centreDescription',
#  u'subCentre',
#  u'tablesVersion',
#  u'masterDir',
#  u'localTablesVersion',
#  u'significanceOfReferenceTime',
#  u'year',
#  u'month',
#  u'day',
#  u'hour',
#  u'minute',
#  u'second',
#  u'dataDate',
#  u'julianDay',
#  u'dataTime',
#  u'productionStatusOfProcessedData',
#  u'typeOfProcessedData',
#  u'selectStepTemplateInterval',
#  u'selectStepTemplateInstant',
#  u'stepType',
#  u'sectionNumber',
#  u'grib2LocalSectionPresent',
#  u'sectionNumber',
#  u'gridDescriptionSectionPresent',
#  u'section3Length',
#  u'numberOfSection',
#  u'sourceOfGridDefinition',
#  u'numberOfDataPoints',
#  u'numberOfOctectsForNumberOfPoints',
#  u'interpretationOfNumberOfPoints',
#  u'PLPresent',
#  u'gridDefinitionTemplateNumber',
#  u'shapeOfTheEarth',
#  u'scaleFactorOfRadiusOfSphericalEarth',
#  u'scaledValueOfRadiusOfSphericalEarth',
#  u'scaleFactorOfEarthMajorAxis',
#  u'scaledValueOfEarthMajorAxis',
#  u'scaleFactorOfEarthMinorAxis',
#  u'scaledValueOfEarthMinorAxis',
#  u'radius',
#  u'Ni',
#  u'Nj',
#  u'basicAngleOfTheInitialProductionDomain',
#  u'mBasicAngle',
#  u'angleMultiplier',
#  u'mAngleMultiplier',
#  u'subdivisionsOfBasicAngle',
#  u'angleDivisor',
#  u'latitudeOfFirstGridPoint',
#  u'longitudeOfFirstGridPoint',
#  u'resolutionAndComponentFlags',
#  u'resolutionAndComponentFlags1',
#  u'resolutionAndComponentFlags2',
#  u'iDirectionIncrementGiven',
#  u'jDirectionIncrementGiven',
#  u'uvRelativeToGrid',
#  u'resolutionAndComponentFlags6',
#  u'resolutionAndComponentFlags7',
#  u'resolutionAndComponentFlags8',
#  u'ijDirectionIncrementGiven',
#  u'latitudeOfLastGridPoint',
#  u'longitudeOfLastGridPoint',
#  u'iDirectionIncrement',
#  u'jDirectionIncrement',
#  u'scanningMode',
#  u'iScansNegatively',
#  u'jScansPositively',
#  u'jPointsAreConsecutive',
#  u'alternativeRowScanning',
#  u'iScansPositively',
#  u'scanningMode5',
#  u'scanningMode6',
#  u'scanningMode7',
#  u'scanningMode8',
#  u'g2grid',
#  u'latitudeOfFirstGridPointInDegrees',
#  u'longitudeOfFirstGridPointInDegrees',
#  u'latitudeOfLastGridPointInDegrees',
#  u'longitudeOfLastGridPointInDegrees',
#  u'iDirectionIncrementInDegrees',
#  u'jDirectionIncrementInDegrees',
#  u'latLonValues',
#  u'latitudes',
#  u'longitudes',
#  u'distinctLatitudes',
#  u'distinctLongitudes',
#  u'gridType',
#  u'sectionNumber',
#  u'section4Length',
#  u'numberOfSection',
#  u'NV',
#  u'neitherPresent',
#  u'productDefinitionTemplateNumber',
#  u'parameterCategory',
#  u'parameterNumber',
#  u'parameterUnits',
#  u'parameterName',
#  u'typeOfGeneratingProcess',
#  u'backgroundProcess',
#  u'generatingProcessIdentifier',
#  u'hoursAfterDataCutoff',
#  u'minutesAfterDataCutoff',
#  u'indicatorOfUnitOfTimeRange',
#  u'stepUnits',
#  u'forecastTime',
#  u'startStep',
#  u'endStep',
#  u'stepRange',
#  u'stepTypeInternal',
#  u'validityDate',
#  u'validityTime',
#  u'typeOfFirstFixedSurface',
#  u'unitsOfFirstFixedSurface',
#  u'nameOfFirstFixedSurface',
#  u'scaleFactorOfFirstFixedSurface',
#  u'scaledValueOfFirstFixedSurface',
#  u'typeOfSecondFixedSurface',
#  u'unitsOfSecondFixedSurface',
#  u'nameOfSecondFixedSurface',
#  u'scaleFactorOfSecondFixedSurface',
#  u'scaledValueOfSecondFixedSurface',
#  u'pressureUnits',
#  u'typeOfLevel',
#  u'level',
#  u'bottomLevel',
#  u'topLevel',
#  u'paramIdECMF',
#  u'paramId',
#  u'shortNameECMF',
#  u'shortName',
#  u'unitsECMF',
#  u'units',
#  u'nameECMF',
#  u'name',
#  u'cfNameECMF',
#  u'cfName',
#  u'ifsParam',
#  u'genVertHeightCoords',
#  u'PVPresent',
#  u'sectionNumber',
#  u'section5Length',
#  u'numberOfSection',
#  u'numberOfValues',
#  u'dataRepresentationTemplateNumber',
#  u'packingType',
#  u'referenceValue',
#  u'referenceValueError',
#  u'binaryScaleFactor',
#  u'decimalScaleFactor',
#  u'bitsPerValue',
#  u'typeOfOriginalFieldValues',
#  u'groupSplittingMethodUsed',
#  u'missingValueManagementUsed',
#  u'primaryMissingValueSubstitute',
#  u'secondaryMissingValueSubstitute',
#  u'numberOfGroupsOfDataValues',
#  u'referenceForGroupWidths',
#  u'numberOfBitsUsedForTheGroupWidths',
#  u'referenceForGroupLengths',
#  u'lengthIncrementForTheGroupLengths',
#  u'trueLengthOfLastGroup',
#  u'numberOfBitsForScaledGroupLengths',
#  u'orderOfSpatialDifferencing',
#  u'numberOfOctetsExtraDescriptors',
#  u'lengthOfHeaders',
#  u'sectionNumber',
#  u'section6Length',
#  u'numberOfSection',
#  u'bitMapIndicator',
#  u'bitmapPresent',
#  u'sectionNumber',
#  u'section7Length',
#  u'numberOfSection',
#  u'codedValues',
#  u'values',
#  u'maximum',
#  u'minimum',
#  u'average',
#  u'numberOfMissing',
#  u'standardDeviation',
#  u'skewness',
#  u'kurtosis',
#  u'isConstant',
#  u'changeDecimalPrecision',
#  u'decimalPrecision',
#  u'setBitsPerValue',
#  u'getNumberOfValues',
#  u'scaleValuesBy',
#  u'offsetValuesBy',
#  u'productType',
#  u'section8Length']
